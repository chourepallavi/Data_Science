# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
anime = pd.read_csv('anime.csv')

# %%
print(f"Shape of The Anime Dataset : {anime.shape}")
print(f"\nGlimpse of The Dataset :")
anime.head().style.set_properties(**{"background-color": "#2a9d8f","color":"white","border": "1.5px  solid black"})
# Out:
# Shape of The Anime Dataset : (12294, 7)
#
# Glimpse of The Dataset :
# <style type="text/css">
# #T_7b964_row0_col0, #T_7b964_row0_col1, #T_7b964_row0_col2, #T_7b964_row0_col3, #T_7b964_row0_col4, #T_7b964_row0_col5, #T_7b964_row0_col6, #T_7b964_row1_col0, #T_7b964_row1_col1, #T_7b964_row1_col2, #T_7b964_row1_col3, #T_7b964_row1_col4, #T_7b964_row1_col5, #T_7b964_row1_col6, #T_7b964_row2_col0, #T_7b964_row2_col1, #T_7b964_row2_col2, #T_7b964_row2_col3, #T_7b964_row2_col4, #T_7b964_row2_col5, #T_7b964_row2_col6, #T_7b964_row3_col0, #T_7b964_row3_col1, #T_7b964_row3_col2, #T_7b964_row3_col3, #T_7b964_row3_col4, #T_7b964_row3_col5, #T_7b964_row3_col6, #T_7b964_row4_col0, #T_7b964_row4_col1, #T_7b964_row4_col2, #T_7b964_row4_col3, #T_7b964_row4_col4, #T_7b964_row4_col5, #T_7b964_row4_col6 {
#   background-color: #2a9d8f;
#   color: white;
#   border: 1.5px  solid black;
# }
# </style>
# <table id="T_7b964">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7b964_level0_col0" class="col_heading level0 col0" >anime_id</th>
#       <th id="T_7b964_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_7b964_level0_col2" class="col_heading level0 col2" >genre</th>
#       <th id="T_7b964_level0_col3" class="col_heading level0 col3" >type</th>
#       <th id="T_7b964_level0_col4" class="col_heading level0 col4" >episodes</th>
#       <th id="T_7b964_level0_col5" class="col_heading level0 col5" >rating</th>
#       <th id="T_7b964_level0_col6" class="col_heading level0 col6" >members</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7b964_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7b964_row0_col0" class="data row0 col0" >32281</td>
#       <td id="T_7b964_row0_col1" class="data row0 col1" >Kimi no Na wa.</td>
#       <td id="T_7b964_row0_col2" class="data row0 col2" >Drama, Romance, School, Supernatural</td>
#       <td id="T_7b964_row0_col3" class="data row0 col3" >Movie</td>
#       <td id="T_7b964_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_7b964_row0_col5" class="data row0 col5" >9.370000</td>
#       <td id="T_7b964_row0_col6" class="data row0 col6" >200630</td>
#     </tr>
#     <tr>
#       <th id="T_7b964_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7b964_row1_col0" class="data row1 col0" >5114</td>
#       <td id="T_7b964_row1_col1" class="data row1 col1" >Fullmetal Alchemist: Brotherhood</td>
#       <td id="T_7b964_row1_col2" class="data row1 col2" >Action, Adventure, Drama, Fantasy, Magic, Military, Shounen</td>
#       <td id="T_7b964_row1_col3" class="data row1 col3" >TV</td>
#       <td id="T_7b964_row1_col4" class="data row1 col4" >64</td>
#       <td id="T_7b964_row1_col5" class="data row1 col5" >9.260000</td>
#       <td id="T_7b964_row1_col6" class="data row1 col6" >793665</td>
#     </tr>
#     <tr>
#       <th id="T_7b964_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7b964_row2_col0" class="data row2 col0" >28977</td>
#       <td id="T_7b964_row2_col1" class="data row2 col1" >Gintama°</td>
#       <td id="T_7b964_row2_col2" class="data row2 col2" >Action, Comedy, Historical, Parody, Samurai, Sci-Fi, Shounen</td>
#       <td id="T_7b964_row2_col3" class="data row2 col3" >TV</td>
#       <td id="T_7b964_row2_col4" class="data row2 col4" >51</td>
#       <td id="T_7b964_row2_col5" class="data row2 col5" >9.250000</td>
#       <td id="T_7b964_row2_col6" class="data row2 col6" >114262</td>
#     </tr>
#     <tr>
#       <th id="T_7b964_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7b964_row3_col0" class="data row3 col0" >9253</td>
#       <td id="T_7b964_row3_col1" class="data row3 col1" >Steins;Gate</td>
#       <td id="T_7b964_row3_col2" class="data row3 col2" >Sci-Fi, Thriller</td>
#       <td id="T_7b964_row3_col3" class="data row3 col3" >TV</td>
#       <td id="T_7b964_row3_col4" class="data row3 col4" >24</td>
#       <td id="T_7b964_row3_col5" class="data row3 col5" >9.170000</td>
#       <td id="T_7b964_row3_col6" class="data row3 col6" >673572</td>
#     </tr>
#     <tr>
#       <th id="T_7b964_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7b964_row4_col0" class="data row4 col0" >9969</td>
#       <td id="T_7b964_row4_col1" class="data row4 col1" >Gintama&#039;</td>
#       <td id="T_7b964_row4_col2" class="data row4 col2" >Action, Comedy, Historical, Parody, Samurai, Sci-Fi, Shounen</td>
#       <td id="T_7b964_row4_col3" class="data row4 col3" >TV</td>
#       <td id="T_7b964_row4_col4" class="data row4 col4" >51</td>
#       <td id="T_7b964_row4_col5" class="data row4 col5" >9.160000</td>
#       <td id="T_7b964_row4_col6" class="data row4 col6" >151266</td>
#     </tr>
#   </tbody>
# </table>

# %%
print(f"Informations About Anime Dataset :\n")
print(anime.info())
# Out:
# Informations About Anime Dataset :
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12294 entries, 0 to 12293
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   anime_id  12294 non-null  int64
#  1   name      12294 non-null  object
#  2   genre     12232 non-null  object
#  3   type      12269 non-null  object
#  4   episodes  12294 non-null  object
#  5   rating    12064 non-null  float64
#  6   members   12294 non-null  int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 672.5+ KB
# None

# %%
print(f"Summary of The Anime Dataset :")
anime.describe().T.style.set_properties(**{"background-color": "#2a9d8f","color":"white","border": "1.5px  solid black"})
# Out:
# Summary of The Anime Dataset :
# <style type="text/css">
# #T_6536a_row0_col0, #T_6536a_row0_col1, #T_6536a_row0_col2, #T_6536a_row0_col3, #T_6536a_row0_col4, #T_6536a_row0_col5, #T_6536a_row0_col6, #T_6536a_row0_col7, #T_6536a_row1_col0, #T_6536a_row1_col1, #T_6536a_row1_col2, #T_6536a_row1_col3, #T_6536a_row1_col4, #T_6536a_row1_col5, #T_6536a_row1_col6, #T_6536a_row1_col7, #T_6536a_row2_col0, #T_6536a_row2_col1, #T_6536a_row2_col2, #T_6536a_row2_col3, #T_6536a_row2_col4, #T_6536a_row2_col5, #T_6536a_row2_col6, #T_6536a_row2_col7 {
#   background-color: #2a9d8f;
#   color: white;
#   border: 1.5px  solid black;
# }
# </style>
# <table id="T_6536a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6536a_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_6536a_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_6536a_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_6536a_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_6536a_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_6536a_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_6536a_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_6536a_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6536a_level0_row0" class="row_heading level0 row0" >anime_id</th>
#       <td id="T_6536a_row0_col0" class="data row0 col0" >12294.000000</td>
#       <td id="T_6536a_row0_col1" class="data row0 col1" >14058.221653</td>
#       <td id="T_6536a_row0_col2" class="data row0 col2" >11455.294701</td>
#       <td id="T_6536a_row0_col3" class="data row0 col3" >1.000000</td>
#       <td id="T_6536a_row0_col4" class="data row0 col4" >3484.250000</td>
#       <td id="T_6536a_row0_col5" class="data row0 col5" >10260.500000</td>
#       <td id="T_6536a_row0_col6" class="data row0 col6" >24794.500000</td>
#       <td id="T_6536a_row0_col7" class="data row0 col7" >34527.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6536a_level0_row1" class="row_heading level0 row1" >rating</th>
#       <td id="T_6536a_row1_col0" class="data row1 col0" >12064.000000</td>
#       <td id="T_6536a_row1_col1" class="data row1 col1" >6.473902</td>
#       <td id="T_6536a_row1_col2" class="data row1 col2" >1.026746</td>
#       <td id="T_6536a_row1_col3" class="data row1 col3" >1.670000</td>
#       <td id="T_6536a_row1_col4" class="data row1 col4" >5.880000</td>
#       <td id="T_6536a_row1_col5" class="data row1 col5" >6.570000</td>
#       <td id="T_6536a_row1_col6" class="data row1 col6" >7.180000</td>
#       <td id="T_6536a_row1_col7" class="data row1 col7" >10.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6536a_level0_row2" class="row_heading level0 row2" >members</th>
#       <td id="T_6536a_row2_col0" class="data row2 col0" >12294.000000</td>
#       <td id="T_6536a_row2_col1" class="data row2 col1" >18071.338864</td>
#       <td id="T_6536a_row2_col2" class="data row2 col2" >54820.676925</td>
#       <td id="T_6536a_row2_col3" class="data row2 col3" >5.000000</td>
#       <td id="T_6536a_row2_col4" class="data row2 col4" >225.000000</td>
#       <td id="T_6536a_row2_col5" class="data row2 col5" >1550.000000</td>
#       <td id="T_6536a_row2_col6" class="data row2 col6" >9437.000000</td>
#       <td id="T_6536a_row2_col7" class="data row2 col7" >1013917.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
anime.describe(include=object).T.style.set_properties(**{"background-color": "#2a9d8f","color":"white","border": "1.5px  solid black"})
# Out:
# <style type="text/css">
# #T_e4b9d_row0_col0, #T_e4b9d_row0_col1, #T_e4b9d_row0_col2, #T_e4b9d_row0_col3, #T_e4b9d_row1_col0, #T_e4b9d_row1_col1, #T_e4b9d_row1_col2, #T_e4b9d_row1_col3, #T_e4b9d_row2_col0, #T_e4b9d_row2_col1, #T_e4b9d_row2_col2, #T_e4b9d_row2_col3, #T_e4b9d_row3_col0, #T_e4b9d_row3_col1, #T_e4b9d_row3_col2, #T_e4b9d_row3_col3 {
#   background-color: #2a9d8f;
#   color: white;
#   border: 1.5px  solid black;
# }
# </style>
# <table id="T_e4b9d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e4b9d_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_e4b9d_level0_col1" class="col_heading level0 col1" >unique</th>
#       <th id="T_e4b9d_level0_col2" class="col_heading level0 col2" >top</th>
#       <th id="T_e4b9d_level0_col3" class="col_heading level0 col3" >freq</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e4b9d_level0_row0" class="row_heading level0 row0" >name</th>
#       <td id="T_e4b9d_row0_col0" class="data row0 col0" >12294</td>
#       <td id="T_e4b9d_row0_col1" class="data row0 col1" >12292</td>
#       <td id="T_e4b9d_row0_col2" class="data row0 col2" >Shi Wan Ge Leng Xiaohua</td>
#       <td id="T_e4b9d_row0_col3" class="data row0 col3" >2</td>
#     </tr>
#     <tr>
#       <th id="T_e4b9d_level0_row1" class="row_heading level0 row1" >genre</th>
#       <td id="T_e4b9d_row1_col0" class="data row1 col0" >12232</td>
#       <td id="T_e4b9d_row1_col1" class="data row1 col1" >3264</td>
#       <td id="T_e4b9d_row1_col2" class="data row1 col2" >Hentai</td>
#       <td id="T_e4b9d_row1_col3" class="data row1 col3" >823</td>
#     </tr>
#     <tr>
#       <th id="T_e4b9d_level0_row2" class="row_heading level0 row2" >type</th>
#       <td id="T_e4b9d_row2_col0" class="data row2 col0" >12269</td>
#       <td id="T_e4b9d_row2_col1" class="data row2 col1" >6</td>
#       <td id="T_e4b9d_row2_col2" class="data row2 col2" >TV</td>
#       <td id="T_e4b9d_row2_col3" class="data row2 col3" >3787</td>
#     </tr>
#     <tr>
#       <th id="T_e4b9d_level0_row3" class="row_heading level0 row3" >episodes</th>
#       <td id="T_e4b9d_row3_col0" class="data row3 col0" >12294</td>
#       <td id="T_e4b9d_row3_col1" class="data row3 col1" >187</td>
#       <td id="T_e4b9d_row3_col2" class="data row3 col2" >1</td>
#       <td id="T_e4b9d_row3_col3" class="data row3 col3" >5677</td>
#     </tr>
#   </tbody>
# </table>

# %%
print("Null Values of Anime Dataset :")
anime.isna().sum().to_frame().T.style.set_properties(**{"background-color": "#2a9d8f","color":"white","border": "1.5px  solid black"})
# Out:
# Null Values of Anime Dataset :
# <style type="text/css">
# #T_a0f25_row0_col0, #T_a0f25_row0_col1, #T_a0f25_row0_col2, #T_a0f25_row0_col3, #T_a0f25_row0_col4, #T_a0f25_row0_col5, #T_a0f25_row0_col6 {
#   background-color: #2a9d8f;
#   color: white;
#   border: 1.5px  solid black;
# }
# </style>
# <table id="T_a0f25">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a0f25_level0_col0" class="col_heading level0 col0" >anime_id</th>
#       <th id="T_a0f25_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_a0f25_level0_col2" class="col_heading level0 col2" >genre</th>
#       <th id="T_a0f25_level0_col3" class="col_heading level0 col3" >type</th>
#       <th id="T_a0f25_level0_col4" class="col_heading level0 col4" >episodes</th>
#       <th id="T_a0f25_level0_col5" class="col_heading level0 col5" >rating</th>
#       <th id="T_a0f25_level0_col6" class="col_heading level0 col6" >members</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a0f25_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a0f25_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_a0f25_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_a0f25_row0_col2" class="data row0 col2" >62</td>
#       <td id="T_a0f25_row0_col3" class="data row0 col3" >25</td>
#       <td id="T_a0f25_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_a0f25_row0_col5" class="data row0 col5" >230</td>
#       <td id="T_a0f25_row0_col6" class="data row0 col6" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
dup_anime = anime[anime.duplicated()].shape[0]
print(f"There are {dup_anime} duplicate entries among {anime.shape[0]} entries in anime dataset.")
# Out:
# There are 0 duplicate entries among 12294 entries in anime dataset.

# %%
print("After Dropping, Null Values of Anime Dataset :")
anime.dropna(axis = 0, inplace = True)
anime.isna().sum().to_frame().T.style.set_properties(**{"background-color": "#2a9d8f","color":"white","border": "1.5px  solid black"})
# Out:
# After Dropping, Null Values of Anime Dataset :
# <style type="text/css">
# #T_1d148_row0_col0, #T_1d148_row0_col1, #T_1d148_row0_col2, #T_1d148_row0_col3, #T_1d148_row0_col4, #T_1d148_row0_col5, #T_1d148_row0_col6 {
#   background-color: #2a9d8f;
#   color: white;
#   border: 1.5px  solid black;
# }
# </style>
# <table id="T_1d148">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1d148_level0_col0" class="col_heading level0 col0" >anime_id</th>
#       <th id="T_1d148_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_1d148_level0_col2" class="col_heading level0 col2" >genre</th>
#       <th id="T_1d148_level0_col3" class="col_heading level0 col3" >type</th>
#       <th id="T_1d148_level0_col4" class="col_heading level0 col4" >episodes</th>
#       <th id="T_1d148_level0_col5" class="col_heading level0 col5" >rating</th>
#       <th id="T_1d148_level0_col6" class="col_heading level0 col6" >members</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1d148_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1d148_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_1d148_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_1d148_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_1d148_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_1d148_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_1d148_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_1d148_row0_col6" class="data row0 col6" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
sns.set_style("white")
sns.set_context("poster",font_scale = .7)

palette = ["#1d7874","#679289","#f4c095","#ee2e31","#ffb563","#918450","#f85e00","#a41623","#9a031e","#d6d6d6","#ffee32","#ffd100","#333533","#202020"]

# %%
top_anime = anime.copy()
top_anime.drop_duplicates(subset ="name", keep = "first", inplace = True)
top_anime_temp1 = top_anime.sort_values(["members"],ascending=False)

plt.subplots(figsize=(20,8))
p = sns.barplot(x=top_anime_temp1["name"][:14],y=top_anime_temp1["members"],palette=palette, saturation=1, edgecolor = "#1c1c1c", linewidth = 2)
p.axes.set_title("\nTop Anime Community\n", fontsize=25)
plt.ylabel("Total Member" , fontsize = 20)
plt.xlabel("\nAnime Name" , fontsize = 20)
# plt.yscale("log")
plt.xticks(rotation = 90)
for container in p.containers:
    p.bar_label(container,label_type = "center",padding = 6,size = 15,color = "black",rotation = 90,
    bbox={"boxstyle": "round", "pad": 0.6, "facecolor": "orange", "edgecolor": "black", "alpha": 1})

sns.despine(left=True, bottom=True)
plt.show()

# %%
print("Anime Categories :")
top_anime_temp1["type"].value_counts().to_frame().T.style.set_properties(**{"background-color": "#2a9d8f","color":"white","border": "1.5px  solid black"})
# Out:
# Anime Categories :
# <style type="text/css">
# #T_467b3_row0_col0, #T_467b3_row0_col1, #T_467b3_row0_col2, #T_467b3_row0_col3, #T_467b3_row0_col4, #T_467b3_row0_col5 {
#   background-color: #2a9d8f;
#   color: white;
#   border: 1.5px  solid black;
# }
# </style>
# <table id="T_467b3">
#   <thead>
#     <tr>
#       <th class="index_name level0" >type</th>
#       <th id="T_467b3_level0_col0" class="col_heading level0 col0" >TV</th>
#       <th id="T_467b3_level0_col1" class="col_heading level0 col1" >OVA</th>
#       <th id="T_467b3_level0_col2" class="col_heading level0 col2" >Movie</th>
#       <th id="T_467b3_level0_col3" class="col_heading level0 col3" >Special</th>
#       <th id="T_467b3_level0_col4" class="col_heading level0 col4" >ONA</th>
#       <th id="T_467b3_level0_col5" class="col_heading level0 col5" >Music</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_467b3_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_467b3_row0_col0" class="data row0 col0" >3668</td>
#       <td id="T_467b3_row0_col1" class="data row0 col1" >3284</td>
#       <td id="T_467b3_row0_col2" class="data row0 col2" >2257</td>
#       <td id="T_467b3_row0_col3" class="data row0 col3" >1670</td>
#       <td id="T_467b3_row0_col4" class="data row0 col4" >648</td>
#       <td id="T_467b3_row0_col5" class="data row0 col5" >488</td>
#     </tr>
#   </tbody>
# </table>

# %%
plt.subplots(figsize=(8, 8))

labels = "TV","OVA","Movie","Special","ONA","Music"
size = 0.5

wedges, texts, autotexts = plt.pie([len(top_anime_temp1[top_anime_temp1["type"]=="TV"]["type"]),
                                    len(top_anime_temp1[top_anime_temp1["type"]=="OVA"]["type"]),
                                    len(top_anime_temp1[top_anime_temp1["type"]=="Movie"]["type"]),
                                    len(top_anime_temp1[top_anime_temp1["type"]=="Special"]["type"]),
                                    len(top_anime_temp1[top_anime_temp1["type"]=="ONA"]["type"]),
                                    len(top_anime_temp1[top_anime_temp1["type"]=="Music"]["type"])],
                                    explode = (0,0,0,0,0,0),
                                    textprops=dict(size= 10, color= "white"),
                                    autopct="%.2f%%", 
                                    pctdistance = 0.7,
                                    radius=.9, 
                                    colors = palette, 
                                    shadow = True,
                                    wedgeprops=dict(width = size, edgecolor = "#1c1c1c", 
                                    linewidth = 2),
                                    startangle = 0)

plt.legend(wedges, labels, title="Category",loc="center left",bbox_to_anchor=(1, 0, 0.5, 1))
plt.title("\nAnime Categories Distribution",fontsize=20)
plt.show()

# %%
plt.subplots(figsize = (20,8))
p = sns.countplot(x = top_anime_temp1["type"], order = top_anime_temp1["type"].value_counts().index, palette = palette, saturation = 1, edgecolor = "#1c1c1c", linewidth = 3)
p.axes.set_title("\nAnime Categories Hub\n" ,fontsize = 25)
plt.ylabel("Total Anime" ,fontsize = 20)
plt.xlabel("\nAnime Category" ,fontsize = 20)
plt.xticks(rotation = 0)
for container in p.containers:
    p.bar_label(container,label_type = "center",padding = 10,size = 25,color = "black",rotation = 0,
    bbox={"boxstyle": "round", "pad": 0.4, "facecolor": "orange", "edgecolor": "black", "linewidth" : 3, "alpha": 1})

sns.despine(left = True, bottom = True)
plt.show()

# %%
top_anime_temp2 = top_anime.sort_values(["rating"],ascending=False)

_, ax = plt.subplots(1,1,figsize=(20,8),sharex=False,sharey=False)
plt.tight_layout(pad=6.0)

sns.histplot(top_anime_temp2["rating"],color=palette[11],kde=True,ax=ax,bins=20,alpha=1,fill=True,edgecolor=palette[12])
ax.lines[0].set_color(palette[12])
ax.set_title("\nAnime's Average Ratings Distribution\n",fontsize = 25)
ax.set_xlabel("Rating\n", fontsize = 20)
ax.set_ylabel("Total", fontsize = 20)
plt.show()

# %%
plt.subplots(figsize=(20,8))
p = sns.barplot(x=top_anime_temp2["name"][:14],y=top_anime_temp2["rating"],palette=palette, saturation=1, edgecolor = "#1c1c1c", linewidth = 2)
p.axes.set_title("\nTop Animes Based On Ratings\n",fontsize = 25)
plt.ylabel("Average Rating",fontsize = 20)
plt.xlabel("\nAnime Title",fontsize = 20)
# plt.yscale("log")
plt.xticks(rotation = 90)
for container in p.containers:
    p.bar_label(container,label_type = "center",padding = 10,size = 15,color = "black",rotation = 0,
    bbox={"boxstyle": "round", "pad": 0.6, "facecolor": "orange", "edgecolor": "black", "alpha": 1})

sns.despine(left=True, bottom=True)
plt.show()

# %%
print("Let's explore the ratings distribution of TV category :\n")
_, ax = plt.subplots(1,1,figsize=(10,8))
sns.histplot(top_anime_temp2[top_anime_temp2["type"]=="TV"]["rating"],color=palette[0],kde=True,ax=ax,bins=20,alpha=1,fill=True,edgecolor=palette[12])
ax.lines[0].set_color(palette[11])
ax.set_title("\nAnime's Average Ratings Distribution [Category : TV]\n",fontsize=20)
ax.set_xlabel("Rating")
ax.set_ylabel("Total")
plt.tight_layout(pad=4.0)
plt.show()
# Out:
# Let's explore the ratings distribution of TV category :

# %%
top_anime_temp3 = top_anime[["genre"]]
top_anime_temp3["genre"] = top_anime_temp3["genre"].str.split(", | , | ,")
top_anime_temp3 = top_anime_temp3.explode("genre")
top_anime_temp3["genre"] = top_anime_temp3["genre"].str.title()

print(f'Total unique genres are {len(top_anime_temp3["genre"].unique())}')
print(f'Occurances of unique genres :')
top_anime_temp3["genre"].value_counts().to_frame().T.style.set_properties(**{"background-color": "#2a9d8f","color":"white","border": "1.5px  solid black"})
# Out:
# Total unique genres are 43
# Occurances of unique genres :
# <style type="text/css">
# #T_b5852_row0_col0, #T_b5852_row0_col1, #T_b5852_row0_col2, #T_b5852_row0_col3, #T_b5852_row0_col4, #T_b5852_row0_col5, #T_b5852_row0_col6, #T_b5852_row0_col7, #T_b5852_row0_col8, #T_b5852_row0_col9, #T_b5852_row0_col10, #T_b5852_row0_col11, #T_b5852_row0_col12, #T_b5852_row0_col13, #T_b5852_row0_col14, #T_b5852_row0_col15, #T_b5852_row0_col16, #T_b5852_row0_col17, #T_b5852_row0_col18, #T_b5852_row0_col19, #T_b5852_row0_col20, #T_b5852_row0_col21, #T_b5852_row0_col22, #T_b5852_row0_col23, #T_b5852_row0_col24, #T_b5852_row0_col25, #T_b5852_row0_col26, #T_b5852_row0_col27, #T_b5852_row0_col28, #T_b5852_row0_col29, #T_b5852_row0_col30, #T_b5852_row0_col31, #T_b5852_row0_col32, #T_b5852_row0_col33, #T_b5852_row0_col34, #T_b5852_row0_col35, #T_b5852_row0_col36, #T_b5852_row0_col37, #T_b5852_row0_col38, #T_b5852_row0_col39, #T_b5852_row0_col40, #T_b5852_row0_col41, #T_b5852_row0_col42 {
#   background-color: #2a9d8f;
#   color: white;
#   border: 1.5px  solid black;
# }
# </style>
# <table id="T_b5852">
#   <thead>
#     <tr>
#       <th class="index_name level0" >genre</th>
#       <th id="T_b5852_level0_col0" class="col_heading level0 col0" >Comedy</th>
#       <th id="T_b5852_level0_col1" class="col_heading level0 col1" >Action</th>
#       <th id="T_b5852_level0_col2" class="col_heading level0 col2" >Adventure</th>
#       <th id="T_b5852_level0_col3" class="col_heading level0 col3" >Fantasy</th>
#       <th id="T_b5852_level0_col4" class="col_heading level0 col4" >Sci-Fi</th>
#       <th id="T_b5852_level0_col5" class="col_heading level0 col5" >Drama</th>
#       <th id="T_b5852_level0_col6" class="col_heading level0 col6" >Shounen</th>
#       <th id="T_b5852_level0_col7" class="col_heading level0 col7" >Kids</th>
#       <th id="T_b5852_level0_col8" class="col_heading level0 col8" >Romance</th>
#       <th id="T_b5852_level0_col9" class="col_heading level0 col9" >Slice Of Life</th>
#       <th id="T_b5852_level0_col10" class="col_heading level0 col10" >School</th>
#       <th id="T_b5852_level0_col11" class="col_heading level0 col11" >Hentai</th>
#       <th id="T_b5852_level0_col12" class="col_heading level0 col12" >Supernatural</th>
#       <th id="T_b5852_level0_col13" class="col_heading level0 col13" >Mecha</th>
#       <th id="T_b5852_level0_col14" class="col_heading level0 col14" >Music</th>
#       <th id="T_b5852_level0_col15" class="col_heading level0 col15" >Historical</th>
#       <th id="T_b5852_level0_col16" class="col_heading level0 col16" >Magic</th>
#       <th id="T_b5852_level0_col17" class="col_heading level0 col17" >Ecchi</th>
#       <th id="T_b5852_level0_col18" class="col_heading level0 col18" >Shoujo</th>
#       <th id="T_b5852_level0_col19" class="col_heading level0 col19" >Sports</th>
#       <th id="T_b5852_level0_col20" class="col_heading level0 col20" >Seinen</th>
#       <th id="T_b5852_level0_col21" class="col_heading level0 col21" >Mystery</th>
#       <th id="T_b5852_level0_col22" class="col_heading level0 col22" >Super Power</th>
#       <th id="T_b5852_level0_col23" class="col_heading level0 col23" >Military</th>
#       <th id="T_b5852_level0_col24" class="col_heading level0 col24" >Parody</th>
#       <th id="T_b5852_level0_col25" class="col_heading level0 col25" >Space</th>
#       <th id="T_b5852_level0_col26" class="col_heading level0 col26" >Horror</th>
#       <th id="T_b5852_level0_col27" class="col_heading level0 col27" >Harem</th>
#       <th id="T_b5852_level0_col28" class="col_heading level0 col28" >Demons</th>
#       <th id="T_b5852_level0_col29" class="col_heading level0 col29" >Martial Arts</th>
#       <th id="T_b5852_level0_col30" class="col_heading level0 col30" >Dementia</th>
#       <th id="T_b5852_level0_col31" class="col_heading level0 col31" >Psychological</th>
#       <th id="T_b5852_level0_col32" class="col_heading level0 col32" >Police</th>
#       <th id="T_b5852_level0_col33" class="col_heading level0 col33" >Game</th>
#       <th id="T_b5852_level0_col34" class="col_heading level0 col34" >Samurai</th>
#       <th id="T_b5852_level0_col35" class="col_heading level0 col35" >Vampire</th>
#       <th id="T_b5852_level0_col36" class="col_heading level0 col36" >Thriller</th>
#       <th id="T_b5852_level0_col37" class="col_heading level0 col37" >Cars</th>
#       <th id="T_b5852_level0_col38" class="col_heading level0 col38" >Shounen Ai</th>
#       <th id="T_b5852_level0_col39" class="col_heading level0 col39" >Shoujo Ai</th>
#       <th id="T_b5852_level0_col40" class="col_heading level0 col40" >Josei</th>
#       <th id="T_b5852_level0_col41" class="col_heading level0 col41" >Yuri</th>
#       <th id="T_b5852_level0_col42" class="col_heading level0 col42" >Yaoi</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b5852_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_b5852_row0_col0" class="data row0 col0" >4574</td>
#       <td id="T_b5852_row0_col1" class="data row0 col1" >2767</td>
#       <td id="T_b5852_row0_col2" class="data row0 col2" >2315</td>
#       <td id="T_b5852_row0_col3" class="data row0 col3" >2241</td>
#       <td id="T_b5852_row0_col4" class="data row0 col4" >2036</td>
#       <td id="T_b5852_row0_col5" class="data row0 col5" >1976</td>
#       <td id="T_b5852_row0_col6" class="data row0 col6" >1684</td>
#       <td id="T_b5852_row0_col7" class="data row0 col7" >1598</td>
#       <td id="T_b5852_row0_col8" class="data row0 col8" >1437</td>
#       <td id="T_b5852_row0_col9" class="data row0 col9" >1204</td>
#       <td id="T_b5852_row0_col10" class="data row0 col10" >1176</td>
#       <td id="T_b5852_row0_col11" class="data row0 col11" >1133</td>
#       <td id="T_b5852_row0_col12" class="data row0 col12" >1001</td>
#       <td id="T_b5852_row0_col13" class="data row0 col13" >929</td>
#       <td id="T_b5852_row0_col14" class="data row0 col14" >842</td>
#       <td id="T_b5852_row0_col15" class="data row0 col15" >798</td>
#       <td id="T_b5852_row0_col16" class="data row0 col16" >747</td>
#       <td id="T_b5852_row0_col17" class="data row0 col17" >628</td>
#       <td id="T_b5852_row0_col18" class="data row0 col18" >594</td>
#       <td id="T_b5852_row0_col19" class="data row0 col19" >533</td>
#       <td id="T_b5852_row0_col20" class="data row0 col20" >532</td>
#       <td id="T_b5852_row0_col21" class="data row0 col21" >485</td>
#       <td id="T_b5852_row0_col22" class="data row0 col22" >451</td>
#       <td id="T_b5852_row0_col23" class="data row0 col23" >416</td>
#       <td id="T_b5852_row0_col24" class="data row0 col24" >402</td>
#       <td id="T_b5852_row0_col25" class="data row0 col25" >377</td>
#       <td id="T_b5852_row0_col26" class="data row0 col26" >362</td>
#       <td id="T_b5852_row0_col27" class="data row0 col27" >313</td>
#       <td id="T_b5852_row0_col28" class="data row0 col28" >287</td>
#       <td id="T_b5852_row0_col29" class="data row0 col29" >264</td>
#       <td id="T_b5852_row0_col30" class="data row0 col30" >238</td>
#       <td id="T_b5852_row0_col31" class="data row0 col31" >226</td>
#       <td id="T_b5852_row0_col32" class="data row0 col32" >195</td>
#       <td id="T_b5852_row0_col33" class="data row0 col33" >177</td>
#       <td id="T_b5852_row0_col34" class="data row0 col34" >146</td>
#       <td id="T_b5852_row0_col35" class="data row0 col35" >100</td>
#       <td id="T_b5852_row0_col36" class="data row0 col36" >86</td>
#       <td id="T_b5852_row0_col37" class="data row0 col37" >72</td>
#       <td id="T_b5852_row0_col38" class="data row0 col38" >62</td>
#       <td id="T_b5852_row0_col39" class="data row0 col39" >54</td>
#       <td id="T_b5852_row0_col40" class="data row0 col40" >52</td>
#       <td id="T_b5852_row0_col41" class="data row0 col41" >41</td>
#       <td id="T_b5852_row0_col42" class="data row0 col42" >38</td>
#     </tr>
#   </tbody>
# </table>

# %%
# !pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.9.4-cp312-cp312-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\dell\anaconda3\lib\site-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in c:\users\dell\anaconda3\lib\site-packages (from wordcloud) (10.3.0)
# Requirement already satisfied: matplotlib in c:\users\dell\anaconda3\lib\site-packages (from wordcloud) (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib->wordcloud) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\dell\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Downloading wordcloud-1.9.4-cp312-cp312-win_amd64.whl (301 kB)
#    ---------------------------------------- 0.0/301.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/301.2 kB ? eta -:--:--
#    - -------------------------------------- 10.2/301.2 kB ? eta -:--:--
#    -- ------------------------------------ 20.5/301.2 kB 217.9 kB/s eta 0:00:02
#    --- ----------------------------------- 30.7/301.2 kB 187.9 kB/s eta 0:00:02
#    ------- ------------------------------- 61.4/301.2 kB 328.2 kB/s eta 0:00:01
#    ----------- --------------------------- 92.2/301.2 kB 403.5 kB/s eta 0:00:01
#    --------------------- ---------------- 174.1/301.2 kB 655.4 kB/s eta 0:00:01
#    --------------------------- ---------- 215.0/301.2 kB 728.8 kB/s eta 0:00:01
#    --------------------------------- ---- 266.2/301.2 kB 746.4 kB/s eta 0:00:01
#    -------------------------------------- 301.2/301.2 kB 775.9 kB/s eta 0:00:00
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.4

# %%
from wordcloud import WordCloud

wordcloud = WordCloud(width = 800, height = 250, background_color ="black",colormap ="RdYlGn",
                      max_font_size=100, stopwords =None,repeat= True).generate(top_anime["genre"].str.cat(sep=", | , | ,"))

print("let's explore how genre's wordcloud looks like\n")
plt.figure(figsize = (20, 8),facecolor = "#ffd100") 
plt.imshow(wordcloud)
plt.axis("off")
plt.margins(x = 0, y = 0)
plt.tight_layout(pad = 0) 
plt.show()
# Out:
# let's explore how genre's wordcloud looks like

# %%
data_pivot_temp = anime.pivot_table(index="name",columns="anime_id",values="rating").fillna(0)
data_pivot_temp.head()
# Out:
# anime_id                                            1      5      6      \
# name
# &quot;0&quot;                                         0.0    0.0    0.0
# &quot;Aesop&quot; no Ohanashi yori: Ushi to Kae...    0.0    0.0    0.0
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...    0.0    0.0    0.0
# &quot;Bungaku Shoujo&quot; Memoire                    0.0    0.0    0.0
# &quot;Bungaku Shoujo&quot; Movie                      0.0    0.0    0.0
#
# anime_id                                            7      8      15     \
# name
# &quot;0&quot;                                         0.0    0.0    0.0
# &quot;Aesop&quot; no Ohanashi yori: Ushi to Kae...    0.0    0.0    0.0
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...    0.0    0.0    0.0
# &quot;Bungaku Shoujo&quot; Memoire                    0.0    0.0    0.0
# &quot;Bungaku Shoujo&quot; Movie                      0.0    0.0    0.0
#
# anime_id                                            16     17     18     \
# name
# &quot;0&quot;                                         0.0    0.0    0.0
# &quot;Aesop&quot; no Ohanashi yori: Ushi to Kae...    0.0    0.0    0.0
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...    0.0    0.0    0.0
# &quot;Bungaku Shoujo&quot; Memoire                    0.0    0.0    0.0
# &quot;Bungaku Shoujo&quot; Movie                      0.0    0.0    0.0
#
# anime_id                                            19     ...  34412  34447  \
# name                                                       ...
# &quot;0&quot;                                         0.0  ...    0.0    0.0
# &quot;Aesop&quot; no Ohanashi yori: Ushi to Kae...    0.0  ...    0.0    0.0
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...    0.0  ...    0.0    0.0
# &quot;Bungaku Shoujo&quot; Memoire                    0.0  ...    0.0    0.0
# &quot;Bungaku Shoujo&quot; Movie                      0.0  ...    0.0    0.0
#
# anime_id                                            34453  34464  34475  \
# name
# &quot;0&quot;                                         0.0    0.0    0.0
# &quot;Aesop&quot; no Ohanashi yori: Ushi to Kae...    0.0    0.0    0.0
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...    0.0    0.0    0.0
# &quot;Bungaku Shoujo&quot; Memoire                    0.0    0.0    0.0
# &quot;Bungaku Shoujo&quot; Movie                      0.0    0.0    0.0
#
# anime_id                                            34476  34490  34503  \
# name
# &quot;0&quot;                                         0.0    0.0    0.0
# &quot;Aesop&quot; no Ohanashi yori: Ushi to Kae...    0.0    0.0    0.0
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...    0.0    0.0    0.0
# &quot;Bungaku Shoujo&quot; Memoire                    0.0    0.0    0.0
# &quot;Bungaku Shoujo&quot; Movie                      0.0    0.0    0.0
#
# anime_id                                            34514  34519
# name
# &quot;0&quot;                                         0.0    0.0
# &quot;Aesop&quot; no Ohanashi yori: Ushi to Kae...    0.0    0.0
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...    0.0    0.0
# &quot;Bungaku Shoujo&quot; Memoire                    0.0    0.0
# &quot;Bungaku Shoujo&quot; Movie                      0.0    0.0
#
# [5 rows x 12017 columns]

# %%
import re
def text_cleaning(text):
    text = re.sub(r'&quot;', '', text)
    text = re.sub(r'.hack//', '', text)
    text = re.sub(r'&#039;', '', text)
    text = re.sub(r'A&#039;s', '', text)
    text = re.sub(r'I&#039;', 'I\'', text)
    text = re.sub(r'&amp;', 'and', text)
    
    return text

anime["name"] = anime["name"].apply(text_cleaning)

# %%
from scipy.sparse import csr_matrix
from sklearn.neighbors import NearestNeighbors

data_matrix = csr_matrix(data_pivot_temp.values)

model_knn = NearestNeighbors(metric = "cosine", algorithm = "brute")
model_knn.fit(data_matrix)

query_no = np.random.choice(data_pivot_temp.shape[0]) # random anime title and finding recommendation
print(f"We will find recommendation for {query_no} no anime which is {data_pivot_temp.index[query_no]}.")
distances, indices = model_knn.kneighbors(data_pivot_temp.iloc[query_no,:].values.reshape(1, -1), n_neighbors = 6)
# Out:
# We will find recommendation for 2544 no anime which is Enzai.

# %%
no = []
name = []
distance = []
rating = []

for i in range(0, len(distances.flatten())):
    if i == 0:
        print(f"Recommendations for {data_pivot_temp.index[query_no]} viewers :\n")
    else:
        #  print(f"{i}: {data_pivot.index[indices.flatten()[i]]} , with distance of {distances.flatten()[i]}")        
        no.append(i)
        name.append(data_pivot_temp.index[indices.flatten()[i]])
        distance.append(distances.flatten()[i])
        rating.append(*anime[anime["name"]==data_pivot_temp.index[indices.flatten()[i]]]["rating"].values)

dic = {"No" : no, "Anime Name" : name, "Rating" : rating}
recommendation = pd.DataFrame(data = dic)
recommendation.set_index("No", inplace = True)
recommendation.style.set_properties(**{"background-color": "#2a9d8f","color":"white","border": "1.5px  solid black"})
# Out:
# Recommendations for Enzai viewers :
# <style type="text/css">
# #T_a2598_row0_col0, #T_a2598_row0_col1, #T_a2598_row1_col0, #T_a2598_row1_col1, #T_a2598_row2_col0, #T_a2598_row2_col1, #T_a2598_row3_col0, #T_a2598_row3_col1, #T_a2598_row4_col0, #T_a2598_row4_col1 {
#   background-color: #2a9d8f;
#   color: white;
#   border: 1.5px  solid black;
# }
# </style>
# <table id="T_a2598">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a2598_level0_col0" class="col_heading level0 col0" >Anime Name</th>
#       <th id="T_a2598_level0_col1" class="col_heading level0 col1" >Rating</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >No</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a2598_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_a2598_row0_col0" class="data row0 col0" >Otona Joshi no Anime Time</td>
#       <td id="T_a2598_row0_col1" class="data row0 col1" >7.520000</td>
#     </tr>
#     <tr>
#       <th id="T_a2598_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_a2598_row1_col0" class="data row1 col0" >Otsuki-sama to Oujo</td>
#       <td id="T_a2598_row1_col1" class="data row1 col1" >6.200000</td>
#     </tr>
#     <tr>
#       <th id="T_a2598_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_a2598_row2_col0" class="data row2 col0" >Otoshidama</td>
#       <td id="T_a2598_row2_col1" class="data row2 col1" >4.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a2598_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_a2598_row3_col0" class="data row3 col0" >Otona no Ikkyuu-san</td>
#       <td id="T_a2598_row3_col1" class="data row3 col1" >5.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a2598_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_a2598_row4_col0" class="data row4 col0" >Ou Dorobou Jing</td>
#       <td id="T_a2598_row4_col1" class="data row4 col1" >7.340000</td>
#     </tr>
#   </tbody>
# </table>

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfv = TfidfVectorizer(min_df=3, max_features=None, strip_accents="unicode", analyzer="word",
                      token_pattern=r"\w{1,}", ngram_range=(1, 3), stop_words = "english")

rec_data = anime.copy()
rec_data.drop_duplicates(subset ="name", keep = "first", inplace = True)
rec_data.reset_index(drop = True, inplace = True)
genres = rec_data["genre"].str.split(", | , | ,").astype(str)
tfv_matrix = tfv.fit_transform(genres)

# %%
from sklearn.metrics.pairwise import sigmoid_kernel

sig = sigmoid_kernel(tfv_matrix, tfv_matrix)      # Computing sigmoid kernel

rec_indices = pd.Series(rec_data.index, index = rec_data["name"]).drop_duplicates()
# Recommendation Function
def give_recommendation(title, sig = sig):
    
    idx = rec_indices[title] # Getting index corresponding to original_title

    sig_score = list(enumerate(sig[idx]))  # Getting pairwsie similarity scores 
    sig_score = sorted(sig_score, key=lambda x: x[1], reverse=True)
    sig_score = sig_score[1:11]
    anime_indices = [i[0] for i in sig_score]
     
    # Top 10 most similar movies
    rec_dic = {"No" : range(1,11), 
               "Anime Name" : anime["name"].iloc[anime_indices].values,
               "Rating" : anime["rating"].iloc[anime_indices].values}
    dataframe = pd.DataFrame(data = rec_dic)
    dataframe.set_index("No", inplace = True)
    
    print(f"Recommendations for {title} viewers :\n")
    
    return dataframe.style.set_properties(**{"background-color": "#2a9d8f","color":"white","border": "1.5px  solid black"})

# %%
give_recommendation("Naruto")
# Out:
# Recommendations for Naruto viewers :
# <style type="text/css">
# #T_db939_row0_col0, #T_db939_row0_col1, #T_db939_row1_col0, #T_db939_row1_col1, #T_db939_row2_col0, #T_db939_row2_col1, #T_db939_row3_col0, #T_db939_row3_col1, #T_db939_row4_col0, #T_db939_row4_col1, #T_db939_row5_col0, #T_db939_row5_col1, #T_db939_row6_col0, #T_db939_row6_col1, #T_db939_row7_col0, #T_db939_row7_col1, #T_db939_row8_col0, #T_db939_row8_col1, #T_db939_row9_col0, #T_db939_row9_col1 {
#   background-color: #2a9d8f;
#   color: white;
#   border: 1.5px  solid black;
# }
# </style>
# <table id="T_db939">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_db939_level0_col0" class="col_heading level0 col0" >Anime Name</th>
#       <th id="T_db939_level0_col1" class="col_heading level0 col1" >Rating</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >No</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_db939_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_db939_row0_col0" class="data row0 col0" >Mobile Suit Gundam Wing: Endless Waltz Movie</td>
#       <td id="T_db939_row0_col1" class="data row0 col1" >7.940000</td>
#     </tr>
#     <tr>
#       <th id="T_db939_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_db939_row1_col0" class="data row1 col0" >Minami-ke</td>
#       <td id="T_db939_row1_col1" class="data row1 col1" >7.810000</td>
#     </tr>
#     <tr>
#       <th id="T_db939_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_db939_row2_col0" class="data row2 col0" >Ashita no Nadja</td>
#       <td id="T_db939_row2_col1" class="data row2 col1" >7.680000</td>
#     </tr>
#     <tr>
#       <th id="T_db939_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_db939_row3_col0" class="data row3 col0" >Hetalia: The World Twinkle</td>
#       <td id="T_db939_row3_col1" class="data row3 col1" >7.580000</td>
#     </tr>
#     <tr>
#       <th id="T_db939_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_db939_row4_col0" class="data row4 col0" >Magic Knight Rayearth</td>
#       <td id="T_db939_row4_col1" class="data row4 col1" >7.530000</td>
#     </tr>
#     <tr>
#       <th id="T_db939_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_db939_row5_col0" class="data row5 col0" >Marmalade Boy Movie</td>
#       <td id="T_db939_row5_col1" class="data row5 col1" >7.500000</td>
#     </tr>
#     <tr>
#       <th id="T_db939_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_db939_row6_col0" class="data row6 col0" >Mouretsu Pirates: Abyss of Hyperspace</td>
#       <td id="T_db939_row6_col1" class="data row6 col1" >7.260000</td>
#     </tr>
#     <tr>
#       <th id="T_db939_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_db939_row7_col0" class="data row7 col0" >Mahoujin Guru Guru Movie</td>
#       <td id="T_db939_row7_col1" class="data row7 col1" >7.110000</td>
#     </tr>
#     <tr>
#       <th id="T_db939_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_db939_row8_col0" class="data row8 col0" >Sign</td>
#       <td id="T_db939_row8_col1" class="data row8 col1" >4.910000</td>
#     </tr>
#     <tr>
#       <th id="T_db939_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_db939_row9_col0" class="data row9 col0" >Columbos</td>
#       <td id="T_db939_row9_col1" class="data row9 col1" >5.220000</td>
#     </tr>
#   </tbody>
# </table>

# %%
give_recommendation("Death Note")
# Out:
# Recommendations for Death Note viewers :
# <style type="text/css">
# #T_dbd27_row0_col0, #T_dbd27_row0_col1, #T_dbd27_row1_col0, #T_dbd27_row1_col1, #T_dbd27_row2_col0, #T_dbd27_row2_col1, #T_dbd27_row3_col0, #T_dbd27_row3_col1, #T_dbd27_row4_col0, #T_dbd27_row4_col1, #T_dbd27_row5_col0, #T_dbd27_row5_col1, #T_dbd27_row6_col0, #T_dbd27_row6_col1, #T_dbd27_row7_col0, #T_dbd27_row7_col1, #T_dbd27_row8_col0, #T_dbd27_row8_col1, #T_dbd27_row9_col0, #T_dbd27_row9_col1 {
#   background-color: #2a9d8f;
#   color: white;
#   border: 1.5px  solid black;
# }
# </style>
# <table id="T_dbd27">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dbd27_level0_col0" class="col_heading level0 col0" >Anime Name</th>
#       <th id="T_dbd27_level0_col1" class="col_heading level0 col1" >Rating</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >No</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dbd27_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_dbd27_row0_col0" class="data row0 col0" >Change!! Getter Robo: Sekai Saigo no Hi</td>
#       <td id="T_dbd27_row0_col1" class="data row0 col1" >7.840000</td>
#     </tr>
#     <tr>
#       <th id="T_dbd27_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_dbd27_row1_col0" class="data row1 col0" >Love Stage!! OVA</td>
#       <td id="T_dbd27_row1_col1" class="data row1 col1" >7.740000</td>
#     </tr>
#     <tr>
#       <th id="T_dbd27_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_dbd27_row2_col0" class="data row2 col0" >One Piece Film: Strong World</td>
#       <td id="T_dbd27_row2_col1" class="data row2 col1" >8.420000</td>
#     </tr>
#     <tr>
#       <th id="T_dbd27_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_dbd27_row3_col0" class="data row3 col0" >Hetalia Axis Powers Fan Disc</td>
#       <td id="T_dbd27_row3_col1" class="data row3 col1" >7.560000</td>
#     </tr>
#     <tr>
#       <th id="T_dbd27_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_dbd27_row4_col0" class="data row4 col0" >Walking Man</td>
#       <td id="T_dbd27_row4_col1" class="data row4 col1" >4.300000</td>
#     </tr>
#     <tr>
#       <th id="T_dbd27_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_dbd27_row5_col0" class="data row5 col0" >Final Fantasy VII: Advent Children Complete</td>
#       <td id="T_dbd27_row5_col1" class="data row5 col1" >8.170000</td>
#     </tr>
#     <tr>
#       <th id="T_dbd27_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_dbd27_row6_col0" class="data row6 col0" >Mobile Fighter G Gundam</td>
#       <td id="T_dbd27_row6_col1" class="data row6 col1" >7.620000</td>
#     </tr>
#     <tr>
#       <th id="T_dbd27_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_dbd27_row7_col0" class="data row7 col0" >Heisei Tanuki Gassen Ponpoko</td>
#       <td id="T_dbd27_row7_col1" class="data row7 col1" >7.420000</td>
#     </tr>
#     <tr>
#       <th id="T_dbd27_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_dbd27_row8_col0" class="data row8 col0" >Kizumonogatari II: Nekketsu-hen</td>
#       <td id="T_dbd27_row8_col1" class="data row8 col1" >8.730000</td>
#     </tr>
#     <tr>
#       <th id="T_dbd27_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_dbd27_row9_col0" class="data row9 col0" >Garo: Honoo no Kokuin - Home</td>
#       <td id="T_dbd27_row9_col1" class="data row9 col1" >6.880000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Interview Questions

# %% [markdown]
# ### 1.What is collaborative filtering, and how does it work?

# %% [raw]
# Collaborative Filtering (CF) is a technique used in recommender systems to predict a user's preferences by analyzing preferences of similar users or items. The core idea is:
#
# "People who agreed in the past will likely agree again in the future."

# %% [raw]
# There are two main types of collaborative filtering:
#
# 1. User-Based Collaborative Filtering
# Goal: Recommend items to a user based on what similar users liked.
#
# Steps:
#
# 1)Find users who are similar to the target user (using similarity measures like cosine similarity or Pearson correlation).
# 2)Recommend items those similar users liked but the target user hasn’t tried yet.
#
# 2. Item-Based Collaborative Filtering
# Goal: Recommend items similar to those the user already liked.
#
# Steps:
#
# 1)Find items similar to those the user has rated or interacted with.
#
# 2Recommend those similar items.

# %% [raw]
# To find similar users or items, collaborative filtering uses:
#
# Cosine Similarity
#
# Pearson Correlation
#
# Jaccard Index (for binary preferences)

# %% [raw]
# --Advantages
# No need for deep understanding of item content.
#
# Can uncover complex, unexpected patterns based on collective behavior.

# %% [raw]
# --Challenges
# Cold Start Problem: Doesn’t work well for new users or new items.
#
# Sparsity: Many users rate only a few items, making similarity hard to compute.
#
# Scalability: Computationally intensive for large datasets.

# %% [markdown]
# ### 2.Can you explain the difference between user-based and item-based collaborative filtering?

# %% [raw]
#  1. User-Based Collaborative Filtering (UBCF)
# "Find users similar to the target user, and recommend what they liked."
#
# -- How it Works:
# -Compare the target user with other users based on rating patterns.
#
# -Recommend items that similar users liked but the target user hasn't seen.
#
# **Example:
# If User A and User B both liked Movie X and Movie Y, and User B also liked Movie Z, recommend Movie Z to User A.
#
# **Similarity Measured Between:
# Users
#
# **Pros:
# Captures personal taste.
#
# Can be effective in small communities or niche domains.
#
# **Cons:
# Doesn’t scale well with millions of users.
#
# Suffers from the cold start problem for new users.

# %% [raw]
# 2. Item-Based Collaborative Filtering (IBCF)
# "Recommend items similar to what the user already liked."
#
# **How it Works:
# Compare items based on how users rated them.
#
# Recommend items that are similar to the ones the user has rated positively.
#
# ** Example:
# If a user liked The Matrix and it is similar to Inception, recommend Inception.
#
# **Similarity Measured Between:
# Items
#
# **Pros:
# More scalable than user-based (items don’t change as frequently).
#
# Works better for platforms with lots of users and fewer items (e.g., Amazon).
#
# **Cons:
# May not capture individual preferences as deeply.
#
# Still needs sufficient user interaction data for items.
